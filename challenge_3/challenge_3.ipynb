# %% [markdown]
# ## Libraries

# %%
#Default
import os
import numpy as np

#Visualisation
import matplotlib.pyplot as plt

#Audio
import librosa
from IPython import display

#ML/DL
import tensorflow as tf

# %% [markdown]
# ## Functions

# %%
#Load data
filePath = './data/Parsed_Capuchinbird_Clips/XC114131-0.wav'

data, sample_rate = librosa.load(filePath)
plt.figure(figsize=(12,5))
librosa.display.waveshow(data, sr=sample_rate)

# %%
sample_rate
# Out:
# 22050

# %%
capuchin_path = os.path.join('data', 'Parsed_Capuchinbird_Clips')
not_capuchin_path = os.path.join('data', 'Parsed_Not_Capuchinbird_Clips')

# %%
capuchin_files = os.listdir(capuchin_path)
not_capuchin_files = os.listdir(not_capuchin_path)

# %%
#Data Size
print(f"Capuchin bird data size: {len(capuchin_files)}")
print(f"Not Capuchin bird data size: {len(not_capuchin_files)}")
# Out:
# Capuchin bird data size: 217
# Not Capuchin bird data size: 593
